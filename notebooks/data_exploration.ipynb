# %%
import numpy as np
import pandas as pd

from predict import read_all_synthetic_curves
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-afa61b9dd989> in <module>
#       2 import pandas as pd
#       3
# ----> 4 from predict import read_all_synthetic_curves
#
# ModuleNotFoundError: No module named 'predict'

# %%
curves = read_all_synthetic_curves('..\..\data')

# %%
print(curves['1'])
# Out:
#         depth       DTC    x    y       DTS   RHOB
# 0        0.00       NaN  0.0  0.0       NaN    NaN
# 1        1.25       NaN  0.0  0.0       NaN    NaN
# 2        2.50       NaN  0.0  0.0       NaN    NaN
# 3        3.75       NaN  0.0  0.0       NaN    NaN
# 4        5.00       NaN  0.0  0.0       NaN    NaN
# ...       ...       ...  ...  ...       ...    ...
# 2796  3495.00  0.000233  0.0  0.0  0.000409  2.566
# 2797  3496.25  0.000233  0.0  0.0  0.000409  2.566
# 2798  3497.50  0.000233  0.0  0.0  0.000409  2.566
# 2799  3498.75  0.000233  0.0  0.0  0.000409  2.566
# 2800  3500.00  0.000233  0.0  0.0  0.000409  2.566
#
# [2801 rows x 6 columns]

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20,6))

curves['1'].DTC.plot(ax=ax1)
curves['1'].DTS.plot(ax=ax2, color='green')
curves['1'].RHOB.plot(ax=ax3, color='red')
fig.show()
# Out:
# C:\Users\gushi\Anaconda3\envs\env_full\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20,6))

curves['2'].DTC.plot(ax=ax1)
curves['2'].DTS.plot(ax=ax2, color='green')
curves['2'].RHOB.plot(ax=ax3, color='red')
fig.show()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20,6))
curves['1'].DTS.plot(ax=ax1)
curves['2'].DTS.plot(ax=ax2)
curves['3'].DTS.plot(ax=ax3)

# %%
plt.plot(curves['1'].DTS)
plt.plot(curves['2'].DTS)
plt.plot(curves['3'].DTS)

# %%
from mpl_toolkits.mplot3d import Axes3D
import random


fig = plt.figure()
ax = Axes3D(fig)

ax.scatter(curves['1'].x, curves['1'].y, curves['1'].depth)
ax.scatter(curves['2'].x, curves['2'].y, curves['2'].depth)
ax.scatter(curves['3'].x, curves['3'].y, curves['3'].depth)
